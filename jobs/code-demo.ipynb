# %%
import requests
import json

YOUTUBE_API_KEY = 'AIzaSyCKq_MgP1CusVZOK7u9vFsGiWf5B3uEsjU'

def get_data_per_page(regionCode, pageToken=None):
    url = f"https://www.googleapis.com/youtube/v3/videos?part=id,snippet,statistics&chart=mostPopular&regionCode={regionCode}&key={YOUTUBE_API_KEY}"
    if pageToken:
        url += f"&pageToken={pageToken}"
    res = requests.get(url)
    data = json.loads(res.content)
    return (data.get('nextPageToken'), data['items'])

def get_trending_video_data(regionCode):
    all_items = []
    next_page_token, items = get_data_per_page(regionCode)
    all_items.extend(items)
    while next_page_token:
        next_page_token, items = get_data_per_page(regionCode, next_page_token)
        all_items.extend(items)
    return all_items

def get_video_categories(regionCode):
    res = requests.get(f"https://www.googleapis.com/youtube/v3/videoCategories?part=snippet&regionCode={regionCode}&key={YOUTUBE_API_KEY}")
    return json.loads(res.content)

# %%
_, data = get_data_per_page('VN')
items_json = json.dumps(data)

# %%
items_json_all = get_trending_video_data('VN')

# %%
dump_json = json.dumps(items_json_all)

# %%
data_json = json.loads(dump_json)

# %%
data_json
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'BwYB2l9JPKudquU5C8mfkO8SGvA',
#   'id': 'rm-4EtvByhA',
#   'snippet': {'publishedAt': '2024-10-17T05:31:13Z',
#    'channelId': 'UC0V3bLajPuERuKwVvGbgtIQ',
#    'title': 'Friends make memories together part 2  | Trà Đặng #short #bestfriend #bff #tiktok',
# ...

# %%
import pandas as pd
df = pd.json_normalize(data_json)

# %%
df_2 = df[['id', 'snippet.publishedAt', 'snippet.channelId', 'snippet.title', 'snippet.description', 'snippet.categoryId', 'snippet.defaultLanguage', 'statistics.viewCount', 'statistics.likeCount', 'statistics.commentCount']]

# %%
df_2.describe()
# Out:
#                  id   snippet.publishedAt         snippet.channelId  \
# count            96                    96                        96
# unique           96                    96                        69
# top     rm-4EtvByhA  2024-10-17T05:31:13Z  UChG2EWuXoW7Tgof35WjbsnQ
# freq              1                     1                         3
#
#                                             snippet.title snippet.description  \
# count                                                  96                  96
# unique                                                 96                  69
# top     Friends make memories together part 2  | Trà Đ...
# freq                                                    1                  15
#
#        snippet.categoryId snippet.defaultLanguage statistics.viewCount  \
# count                  96                      96                   96
# unique                 12                       7                   96
# ...

# %%
len(df_2)
# Out:
# 96

# %%
df_2['snippet.defaultLanguage'].fillna('none')
df_2['statistics.commentCount'].fillna(0)
df_2['statistics.viewCount'].fillna(0)
df_2['statistics.likeCount'].fillna(0)
# Out:
# 0      283158
# 1       16495
# 2     3527514
# 3       19867
# 4       32632
#        ...
# 91     215509
# 92     165704
# 93      37664
# 94      69656
# 95      34503
# Name: statistics.likeCount, Length: 96, dtype: object

# %%
df_3 = df_2.dropna()
len(df_3)
# Out:
# 96

# %%
df
# Out:
#              kind                         etag           id  \
# 0   youtube#video  BwYB2l9JPKudquU5C8mfkO8SGvA  rm-4EtvByhA
# 1   youtube#video  gGTeT0Hnjnv-y58XLkZiNeJIAh8  aMxvY0IldwM
# 2   youtube#video  46H-gnefKia-dNCz4si9g6Hgp0M  ekr2nIex040
# 3   youtube#video  RhEYKCocRrVvHuMGbc9ozEICUx0  i-2LhJamMpU
# 4   youtube#video  bc-Ogya3yFtQvvZBvT9ph3i-ggk  8dFbeBWzxHA
# ..            ...                          ...          ...
# 91  youtube#video  ybwtc8M8i_fQ8shF2GhHKsp0pXw  swKBCH7oMHA
# 92  youtube#video  Dkk0HteSLDdusws5Ma0uw3jXOe4  rAjeebMOnKk
# 93  youtube#video  Tt2DIwIQbSqxpDRsegjHwiqCOAs  JnfPCT4s5oA
# 94  youtube#video  38jkEsiO9ljuFZ-8ZjbNIr1n6kQ  oGqAHsKbtlE
# 95  youtube#video  pcnlejIbipuQZ20IFzhpDs6sG_k  Bw1ljIAB-s0
#
#      snippet.publishedAt         snippet.channelId  \
# 0   2024-10-17T05:31:13Z  UC0V3bLajPuERuKwVvGbgtIQ
# 1   2024-10-16T04:05:16Z  UC_3p3K5B2OYmyOmgxlVLgOA
# 2   2024-10-18T04:00:07Z  UCBo1hnzxV9rz3WVsv__Rn1g
# ...
